# %% [markdown]
# # 🔊 RVC - Voice Changer + Ngrok
# ### Acesso via navegador
# ### Funciona com ngrok FREE
# ---

# %% [markdown]
# ## 📌 Instalar dependências

# %%
# !apt-get update -y
# !apt-get install ffmpeg -y
# !pip install torch torchvision torchaudio --index_url https://download.pytorch.org/whl/cu118
# !pip install gradio==3.50.2
# !pip install soundfile librosa numpy==1.23.5

# %% [markdown]
# ## 📌 Baixar RVC WebUI

# %%
# !git clone https://github.com/RVC-Project/Retrieval-based-Voice-Conversion-WebUI.git
# %cd Retrieval-based-Voice-Conversion-WebUI
# !pip install -r requirements.txt

# %% [markdown]
# ## 🔑 ngrok — Coloque seu token AQUI
# ### ❗ NÃO compartilhe este token com ninguém

# %%
NGROK_TOKEN = "COLOQUE_SEU_TOKEN_AQUI"  # ⬅️ EDITE ESTA LINHA
# !pip install pyngrok
from pyngrok import ngrok
ngrok.set_auth_token(NGROK_TOKEN)

# %% [markdown]
# ## 🚀 Iniciar WebUI + ngrok

# %%
public_url = ngrok.connect(7865)
print("🔗 SUA URL DE ACESSO EXTERNO:", public_url)
# !python webui.py --port 7865
